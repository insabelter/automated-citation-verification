# %% [markdown]
# # Identify the 3 top matching chunks using LlamaIndex

# %% [markdown]
# LlamaIndex:
# - Github: https://github.com/run-llama/llama_index
# - Documentation: https://docs.llamaindex.ai/en/latest/

# %%
import pandas as pd

# read the xlsx data into a pandas dataframe
df = pd.read_excel('../data/ReferenceErrorDetection_data.xlsx')

# %%
df.head()
# Out:
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain  \
# 0                       Yes  Engineering
# 1                       Yes  Engineering
# 2                       Yes    Chemistry
# 3                       Yes     Medicine
# 4                       Yes  Engineering
#
#                              Statement with Citation Reference Article ID  \
# 0  Others have aimed to reduce irreversibility or...                 r001
# 1  Some researchers have also studied various hea...                 r002
# 2  The relative content of total flavonoids in th...                 r003
# 3  Research has shown that remimazolam tosylate e...                 r004
# 4  if the efficiency of the routing algorithm is ...                 r005
#
#              Reference Article DOI  \
# 0             10.1155/2021/2087027
# 1      10.1016/j.physa.2018.12.031
# 2  10.1088/1742-6596/1937/1/012038
# 3        10.1186/s12871-018-0543-3
# 4      10.36410/jcpr.2022.23.3.312
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded           Label Explanation
# 0                          Yes  Unsubstantiate  Irrelevant
# 1                          Yes  Unsubstantiate  Irrelevant
# 2                          Yes  Unsubstantiate  Irrelevant
# 3                          Yes  Unsubstantiate  Irrelevant
# 4                          Yes  Unsubstantiate  Irrelevant

# %%
first_entry = df.query("`Reference Article Retracted` == 'No' and `Label` == 'Fully substantiate'").iloc[0]
first_entry
# Out:
# Source                                                     Smith & Cumberledge, 2020
# Citing Article ID                                                               c058
# Citing Article DOI                                           10.1126/science.aan0177
# Citing Article Title               High dislocation density-induced large ductili...
# Citing Article Retracted                                                          No
# Citing Article Downloaded                                                        Yes
# Domain                                                                       Physics
# Statement with Citation            Tensile properties of our steel compared with ...
# Reference Article ID                                                            r091
# Reference Article DOI                                     10.2320/matertrans.46.1839
# Reference Article Title            The role of retained austenite on tensile prop...
# Reference Article Abstract         In high-carbon, silicon-rich steels it is poss...
# Reference Article PDF Available                                                  Yes
# Reference Article Retracted                                                       No
# Reference Article Downloaded                                                     Yes
# Label                                                             Fully substantiate
# Explanation                                                                     Data
# Name: 97, dtype: object

# %%
first_entry_id = first_entry['Reference Article ID']
first_entry_id
# Out:
# 'r091'

# %% [markdown]
# ## Get text from reference article

# %%
grobid_model = "small_model"
extension = "xml"

# %%
import glob

def get_file_path(reference_article_id):
    # Construct the file path pattern using the Reference Article ID of the first entry
    file_pattern = f"../data/extractions/{grobid_model}/{reference_article_id}*.{extension}"

    # Find the file that matches the pattern
    file_list = glob.glob(file_pattern)
    if file_list:
        file_path = file_list[0]
        return file_path
    else: 
        print("No matching file found.")
        return None

# %%
import xml.etree.ElementTree as ET

def get_reference_text(reference_article_id):
    global extension
    
    # Get the file path
    file_path = get_file_path(reference_article_id)
    
    if file_path:
        if extension == "txt":
            # Read the text file
            with open(file_path, 'r') as file:
                reference_text = file.read()
            return reference_text

        elif extension == "xml":
            # Parse the XML file
            tree = ET.parse(file_path)
            root = tree.getroot()

            # Extract the text content from the XML file
            reference_text = ''.join(root.itertext())
            return reference_text

# %%
reference_text = get_reference_text(first_entry_id)

# %%
reference_text
# Out:
# '\n\t\n\t\t\n\t\t\t\n\t\t\t\tThe Role of Retained Austenite on Tensile Properties of Steels with Bainitic Microstructures\n\t\t\t\t\n\t\t\t\t\tSpanish Ministerio de Ciencia y Tecnologı\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\tEPSRC/MOD\n\t\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\tAugust 15, 2005\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\tCarlosGarcı ´a-Mateo\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tDepartment of Physical Metallurgy\n\t\t\t\t\t\t\t\tMateralia Research Group. Centro Nacional de Investigaciones Metalu ´rgicas (CENIM-CSIC)\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAvda. Gregorio del Amo, 8\n\t\t\t\t\t\t\t\t\t28040\n\t\t\t\t\t\t\t\t\tMadrid\n\t\t\t\t\t\t\t\t\tSpain\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\tFranciscaGCaballero\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tDepartment of Physical Metallurgy\n\t\t\t\t\t\t\t\tMateralia Research Group. Centro Nacional de Investigaciones Metalu ´rgicas (CENIM-CSIC)\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAvda. Gregorio del Amo, 8\n\t\t\t\t\t\t\t\t\t28040\n\t\t\t\t\t\t\t\t\tMadrid\n\t\t\t\t\t\t\t\t\tSpain\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\tCSi\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tDepartment of Physical Metallurgy\n\t\t\t\t\t\t\t\tMateralia Research Group. Centro Nacional de Investigaciones Metalu ´rgicas (CENIM-CSIC)\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAvda. Gregorio del Amo, 8\n\t\t\t\t\t\t\t\t\t28040\n\t\t\t\t\t\t\t\t\tMadrid\n\t\t\t\t\t\t\t\t\tSpain\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\tMnMo\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\tDepartment of Physical Metallurgy\n\t\t\t\t\t\t\t\tMateralia Research Group. Centro Nacional de Investigaciones Metalu ´rgicas (CENIM-CSIC)\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAvda. Gregorio del Amo, 8\n\t\t\t\t\t\t\t\t\t28040\n\t\t\t\t\t\t\t\t\tMadrid\n\t\t\t\t\t\t\t\t\tSpain\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\tThe Role of Retained Austenite on Tensile Properties of Steels with Bainitic Microstructures\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\t\n\t\t\t\t\t\t\tAugust 15, 2005\n\t\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t3AE8B8B2D1625742C8A25FD11E317684\n\t\t\t\t\tReceived March 1, 2005; Accepted June 8, 2005;\n\t\t\t\t\n\t\t\t\n\t\t\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\tGROBID - A machine learning software for extracting information from scholarly documents\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\n\t\t\n\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\tBainite\n\t\t\t\t\tretained austenite\n\t\t\t\t\tmechanical stability\n\t\t\t\t\tmorphology\n\t\t\t\t\tchemical composition\n\t\t\t\t\tductility\n\t\t\t\t\tstrength\n\t\t\t\t\n\t\t\t\n\t\t\t\nIn high-carbon, silicon-rich steels it is possible to obtain a very fine bainitic microstructure by transformation at low temperatures (200-300 C). This microstructure consists of slender ferrite plates, with thicknesses of several tens of nm, in a matrix of retained austenite. Whereas strength is mainly provided by to the fine scale of the ferrite plates (stronger phase), ductility is mostly controlled by the retained austenite (softer phase). Further improvement in ductility is achieved by strain induced transformation of austenite to martensite, the so called TRIP effect. In order to take full advantage of this effect, the mechanical stability of the austenite, i.e., its capability to transform to martensite under strain, must not be too low nor excessively high.Two main aspects of the mechanical stability of the retained austenite, morphology and chemical composition, have been studied to determine the role that these play on the ductility behaviour of the bainitic steels studied. It is suggested that the chemical composition has the strongest effect on the ductility of these new high strength alloys.\n\t\t\t\n\t\t\n\t\n\t\n\t\t\nIntroductionBy means of phase transformation theory for the bainite reaction, high-carbon, silicon-rich steels have been developed 1,2) with bainite transformation tempera ...

# %% [markdown]
# ## Set OpenAI key

# %%
# Read the content of open_ai_key.txt into a variable
with open('../open_ai_key.txt', 'r') as file:
    open_ai_key = file.read().strip()

# %% [markdown]
# ## Setting up vector index

# %% [markdown]
# ### Chunk splitting

# %%
from llama_index.core.node_parser import TokenTextSplitter

def create_chunks(text, chunk_size=256, chunk_overlap=20):
    token_text_splitter = TokenTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    chunks = token_text_splitter.split_text(text)
    return chunks

# %%
reference_chunks = create_chunks(reference_text)

# %% [markdown]
# ### Reloading or generating index

# %%
model = "gpt-3.5-turbo-0125"
model_embeddings = "text-embedding-3-small"

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import Settings
from llama_index.llms.openai import OpenAI

Settings.embed_model = OpenAIEmbedding(model=model_embeddings, api_key=open_ai_key)
Settings.llm = OpenAI(model=model, temperature=0)

# %%
from llama_index.core import StorageContext, load_index_from_storage
from llama_index.core import VectorStoreIndex, Document

def load_or_create_index(article_id, reference_chunks):
    index_path = f"../data/vector_indices/{grobid_model}/{article_id}/"
    index = None

    try:
        storage_context = StorageContext.from_defaults(persist_dir=index_path)
        index = load_index_from_storage(storage_context)
        print(article_id + ": Loaded existing index.")
    except Exception as e:
        print(e)
        print(article_id + ": Creating a new index.")
        documents = [Document(text=chunk) for chunk in reference_chunks]
        index = VectorStoreIndex.from_documents(documents)
        index.storage_context.persist(persist_dir=index_path)
    
    return index

# %%
index = load_or_create_index(first_entry_id, reference_chunks)
# Out:
# r091: Loaded existing index.

# %% [markdown]
# ### Create Indices for all reference articles

# %%
for _, row in df.iterrows():
    if row['Reference Article Downloaded'] == 'Yes':
        reference_article_id = row['Reference Article ID']
        reference_text = get_reference_text(reference_article_id)
        reference_chunks = create_chunks(reference_text)
        index = load_or_create_index(reference_article_id, reference_chunks)
# Out:
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r001/docstore.json'
# r001: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r002/docstore.json'
# r002: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r003/docstore.json'
# r003: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r004/docstore.json'
# r004: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r005/docstore.json'
# r005: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r006/docstore.json'
# r006: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r007/docstore.json'
# r007: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r008/docstore.json'
# r008: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r009/docstore.json'
# r009: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r010/docstore.json'
# r010: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r011/docstore.json'
# r011: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r012/docstore.json'
# r012: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r013/docstore.json'
# r013: Creating a new index.
# r013: Loaded existing index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r014/docstore.json'
# r014: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r015/docstore.json'
# r015: Creating a new index.
# r005: Loaded existing index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r017/docstore.json'
# r017: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r018/docstore.json'
# r018: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r019/docstore.json'
# r019: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r020/docstore.json'
# r020: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r021/docstore.json'
# r021: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r022/docstore.json'
# r022: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r023/docstore.json'
# r023: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r024/docstore.json'
# r024: Creating a new index.
# r013: Loaded existing index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r025/docstore.json'
# r025: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r026/docstore.json'
# r026: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r027/docstore.json'
# r027: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r028/docstore.json'
# r028: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r029/docstore.json'
# r029: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r030/docstore.json'
# r030: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r031/docstore.json'
# r031: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r032/docstore.json'
# r032: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r033/docstore.json'
# r033: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r034/docstore.json'
# r034: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r035/docstore.json'
# r035: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r036/docstore.json'
# r036: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r037/docstore.json'
# r037: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r038/docstore.json'
# r038: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r039/docstore.json'
# r039: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r040/docstore.json'
# r040: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r041/docstore.json'
# r041: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r042/docstore.json'
# r042: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r043/docstore.json'
# r043: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r044/docstore.json'
# r044: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r045/docstore.json'
# r045: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r046/docstore.json'
# r046: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r047/docstore.json'
# r047: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r048/docstore.json'
# r048: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r049/docstore.json'
# r049: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r050/docstore.json'
# r050: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r051/docstore.json'
# r051: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r052/docstore.json'
# r052: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r053/docstore.json'
# r053: Creating a new index.
# r051: Loaded existing index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r055/docstore.json'
# r055: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r056/docstore.json'
# r056: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r057/docstore.json'
# r057: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r058/docstore.json'
# r058: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r059/docstore.json'
# r059: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r060/docstore.json'
# r060: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r061/docstore.json'
# r061: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r062/docstore.json'
# r062: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r063/docstore.json'
# r063: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r064/docstore.json'
# r064: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r065/docstore.json'
# r065: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r066/docstore.json'
# r066: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r067/docstore.json'
# r067: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r068/docstore.json'
# r068: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r069/docstore.json'
# r069: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r070/docstore.json'
# r070: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r071/docstore.json'
# r071: Creating a new index.
# Some nodes are missing content, skipping them...
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r072/docstore.json'
# r072: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r074/docstore.json'
# r074: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r075/docstore.json'
# r075: Creating a new index.
# Some nodes are missing content, skipping them...
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r076/docstore.json'
# r076: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r077/docstore.json'
# r077: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r078/docstore.json'
# r078: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r079/docstore.json'
# r079: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r080/docstore.json'
# r080: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r081/docstore.json'
# r081: Creating a new index.
# r081: Loaded existing index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r082/docstore.json'
# r082: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r083/docstore.json'
# r083: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r084/docstore.json'
# r084: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r085/docstore.json'
# r085: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r086/docstore.json'
# r086: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r087/docstore.json'
# r087: Creating a new index.
# r087: Loaded existing index.
# r087: Loaded existing index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r088/docstore.json'
# r088: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r089/docstore.json'
# r089: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r090/docstore.json'
# r090: Creating a new index.
# r091: Loaded existing index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r092/docstore.json'
# r092: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r093/docstore.json'
# r093: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r094/docstore.json'
# r094: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r095/docstore.json'
# r095: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r096/docstore.json'
# r096: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r097/docstore.json'
# r097: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r098/docstore.json'
# r098: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r099/docstore.json'
# r099: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r100/docstore.json'
# r100: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r101/docstore.json'
# r101: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r102/docstore.json'
# r102: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r103/docstore.json'
# r103: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r104/docstore.json'
# r104: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r105/docstore.json'
# r105: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r106/docstore.json'
# r106: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r107/docstore.json'
# r107: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r108/docstore.json'
# r108: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r109/docstore.json'
# r109: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r110/docstore.json'
# r110: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r111/docstore.json'
# r111: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r112/docstore.json'
# r112: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r113/docstore.json'
# r113: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r114/docstore.json'
# r114: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r115/docstore.json'
# r115: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r116/docstore.json'
# r116: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r117/docstore.json'
# r117: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r118/docstore.json'
# r118: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r119/docstore.json'
# r119: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r120/docstore.json'
# r120: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r121/docstore.json'
# r121: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r122/docstore.json'
# r122: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r123/docstore.json'
# r123: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r124/docstore.json'
# r124: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r125/docstore.json'
# r125: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r126/docstore.json'
# r126: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r127/docstore.json'
# r127: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r128/docstore.json'
# r128: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r129/docstore.json'
# r129: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r130/docstore.json'
# r130: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r131/docstore.json'
# r131: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r132/docstore.json'
# r132: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r133/docstore.json'
# r133: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r134/docstore.json'
# r134: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r135/docstore.json'
# r135: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r136/docstore.json'
# r136: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r137/docstore.json'
# r137: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r138/docstore.json'
# r138: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r139/docstore.json'
# r139: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r140/docstore.json'
# r140: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r141/docstore.json'
# r141: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r142/docstore.json'
# r142: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r143/docstore.json'
# r143: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r144/docstore.json'
# r144: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r145/docstore.json'
# r145: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r146/docstore.json'
# r146: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r147/docstore.json'
# r147: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r148/docstore.json'
# r148: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r149/docstore.json'
# r149: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r150/docstore.json'
# r150: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r151/docstore.json'
# r151: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r152/docstore.json'
# r152: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r153/docstore.json'
# r153: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r154/docstore.json'
# r154: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r155/docstore.json'
# r155: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r156/docstore.json'
# r156: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r157/docstore.json'
# r157: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r158/docstore.json'
# r158: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r159/docstore.json'
# r159: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r160/docstore.json'
# r160: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r161/docstore.json'
# r161: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r162/docstore.json'
# r162: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r163/docstore.json'
# r163: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r164/docstore.json'
# r164: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r165/docstore.json'
# r165: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r166/docstore.json'
# r166: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r167/docstore.json'
# r167: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r168/docstore.json'
# r168: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r169/docstore.json'
# r169: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r170/docstore.json'
# r170: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r171/docstore.json'
# r171: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r172/docstore.json'
# r172: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r173/docstore.json'
# r173: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r174/docstore.json'
# r174: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r175/docstore.json'
# r175: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r176/docstore.json'
# r176: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r177/docstore.json'
# r177: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r178/docstore.json'
# r178: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r179/docstore.json'
# r179: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r180/docstore.json'
# r180: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r181/docstore.json'
# r181: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r182/docstore.json'
# r182: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r183/docstore.json'
# r183: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r184/docstore.json'
# r184: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r185/docstore.json'
# r185: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r186/docstore.json'
# r186: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r187/docstore.json'
# r187: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r188/docstore.json'
# r188: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r189/docstore.json'
# r189: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r190/docstore.json'
# r190: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r191/docstore.json'
# r191: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r192/docstore.json'
# r192: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r193/docstore.json'
# r193: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r194/docstore.json'
# r194: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r195/docstore.json'
# r195: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r196/docstore.json'
# r196: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r197/docstore.json'
# r197: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r198/docstore.json'
# r198: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r199/docstore.json'
# r199: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r200/docstore.json'
# r200: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r201/docstore.json'
# r201: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r202/docstore.json'
# r202: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r203/docstore.json'
# r203: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r204/docstore.json'
# r204: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r205/docstore.json'
# r205: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r206/docstore.json'
# r206: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r207/docstore.json'
# r207: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r208/docstore.json'
# r208: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r209/docstore.json'
# r209: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r210/docstore.json'
# r210: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r211/docstore.json'
# r211: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r212/docstore.json'
# r212: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r213/docstore.json'
# r213: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r214/docstore.json'
# r214: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r215/docstore.json'
# r215: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r216/docstore.json'
# r216: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r217/docstore.json'
# r217: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r218/docstore.json'
# r218: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r219/docstore.json'
# r219: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r220/docstore.json'
# r220: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r221/docstore.json'
# r221: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r222/docstore.json'
# r222: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r223/docstore.json'
# r223: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r224/docstore.json'
# r224: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r225/docstore.json'
# r225: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r226/docstore.json'
# r226: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r227/docstore.json'
# r227: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r228/docstore.json'
# r228: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r229/docstore.json'
# r229: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r230/docstore.json'
# r230: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r231/docstore.json'
# r231: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r232/docstore.json'
# r232: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r233/docstore.json'
# r233: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r234/docstore.json'
# r234: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r235/docstore.json'
# r235: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r236/docstore.json'
# r236: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r237/docstore.json'
# r237: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r238/docstore.json'
# r238: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r239/docstore.json'
# r239: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r240/docstore.json'
# r240: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r241/docstore.json'
# r241: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r242/docstore.json'
# r242: Creating a new index.
# [Errno 2] No such file or directory: '/home/ibelter/master_thesis/citation-verification/notebooks/../data/vector_indices/full_model_texts/r243/docstore.json'
# r243: Creating a new index.

# %% [markdown]
# ## Identifying top 3 chunks

# %%
statement = first_entry["Statement with Citation"]
statement
# Out:
# 'Tensile properties of our steel compared with those of other existing high strength metallic materials. These include nanobainite steel [citation 36].'

# %%
from llama_index.core import get_response_synthesizer
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine

def get_top_k_similar_statements(statement, index, k=3):
    retriever = VectorIndexRetriever(
        index=index,
        similarity_top_k=k,
    )
    response_synthesizer = get_response_synthesizer(
        response_mode="no_text",
    )
    query_engine = RetrieverQueryEngine(
        retriever=retriever,
        response_synthesizer=response_synthesizer,
    )
    response = query_engine.query(statement)
    return response

# %%
response = get_top_k_similar_statements(statement, index)
response
# Out:
# Response(response='', source_nodes=[NodeWithScore(node=TextNode(id_='8c3b39ce-ab7d-4020-8e44-2067f0c8bb15', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='09c468d8-a386-423f-9853-a0257dc6abf9', node_type='4', metadata={}, hash='f8b60ca3481c74f17510a46adc72b0094e923b122ced363bba1f03c5eb48d376')}, metadata_template='{key}: {value}', metadata_separator='\n', text='optical axis is free of dispersion of the resonator, as we could keep the desired anisotropic behavior. To verify our proposed scheme, we have performed full-wave simulations using CST Microwave Studio, based on the finite difference time domain (FDTD) algorithm  [28] . We utilize the perfect conductor approximation (PCA) for simplicity. The results presented here can be extended to other frequency regimes, when the dispersion of metal is taken into consideration. We focus on the wavelength λ = 2.21a(3.68b), where the element of transmission matrix fulfills 1 2 t t -\uf03b . In the y direction, we adopt periodic condition, while in the x direction, perfectly matched layer absorbing boundary condition is adopted. We set the mesh size to be 0.01a-0.02a in the transverse direction and 0.02a-0.05a in the longitudinal z direction. The mesh size with high precision enables us to model the array of the metallic apertures exhibiting inhomogeneous and anisotropic EM responses with high accuracy.\n\nLight bending through phase discontinuities across an ultra-thin metamaterial surface\nAs depicted in Fig.  1 , a representative structure (A) with', mimetype='text/plain', start_char_idx=0, end_char_idx=1144, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.2889721934983853), NodeWithScore(node=TextNode(id_='de796540-5d9a-4d01-b50e-96075b1cce6f', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='61d7d3f6-52c8-45b4-8d44-b376fb9441bd', node_type='4', metadata={}, hash='d0ab1485e68228bf4eeffd34afe5ccbbac758cc1b1dfe5f4fdf0efb1305eb593')}, metadata_template='{key}: {value}', metadata_separator='\n', text="Introduction\nMetamaterials (MMs), as a new type of artificially structured materials, have been used to demonstrate exotic phenomena such as negative refraction  [1, 2]  and invisibility cloaking  [3, 4] . Because metamaterials can provide extreme electromagnetic (EM) response to the incident light with the subwavelength resonating units, it becomes possible to achieve considerable electromagnetic response by just using a slab of metamaterial which is much thinner than a wavelength. For example, an ultra-thin metamaterial can be used to perfectly absorb light  [5, 6]  and to generate large optical chirality for polarization manipulation  [7, 8] . Recently, such an approach has been extended to extreme phase control. By using an array of metamaterial units of structural parameters varying on a subwavelength scale, the light incident on an ultrathin metamaterial can be bent by an angle using the phase discontinuity across the metamaterial, in a way that the Snell's law has been generalized on an inhomogeneous metamaterial surface  [9] [10] [11] [12] [13] . In contrast to the ordinary spatial phase modulation devices employing liquid crystals  [14,", mimetype='text/plain', start_char_idx=0, end_char_idx=1163, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.25298701007530844), NodeWithScore(node=TextNode(id_='fa63a1b3-8228-4614-80a9-952bb48f4ed9', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='2c70cef4-1c2f-43a2-a766-87382889d617', node_type='4', metadata={}, hash='3a4c2b46a98b9b03e1cc720754138d9b8c23c73b602f064ca85dd3139edab60e')}, metadata_template='{key}: {value}', metadata_separator ...

# %%
def get_doc_ids(response, index):
    doc_ids = []
    for source_node in response.source_nodes:
        node_id = source_node.dict()['node']['relationships']['1']['node_id']
        doc_ids.append([doc_id for doc_id, doc in index.docstore.docs.items() if doc.dict()['relationships']['1']['node_id'] == node_id][0])
    return doc_ids

# %%
get_doc_ids(response, index)
# Out:
# ['8c3b39ce-ab7d-4020-8e44-2067f0c8bb15',
#  'de796540-5d9a-4d01-b50e-96075b1cce6f',
#  'fa63a1b3-8228-4614-80a9-952bb48f4ed9']

# %%
import json
import os

def save_similar_chunks(doc_ids, reference_id):
    file_path = f"../data/similar_chunks/{grobid_model}/{reference_id}.json"
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    with open(file_path, 'w') as file:
        json.dump(doc_ids, file)

def load_similar_chunks(reference_id):
    file_path = f"../data/similar_chunks/{grobid_model}/{reference_id}.json"
    with open(file_path, 'r') as file:
        doc_ids = json.load(file)
    return doc_ids

# %%
save_similar_chunks(get_doc_ids(response, index), first_entry_id)

# %% [markdown]
# ### Save the document ids and text contents of the top k chunks of all reference articles to the df

# %%
def save_top_k_chunk_ids(df, k=3):
    for _, row in df.iterrows():
        if row['Reference Article Downloaded'] == 'Yes':
            reference_article_id = row['Reference Article ID']
            print(f"------ Starting {reference_article_id} ------")
            
            # Try to load similar chunks first
            try:
                doc_ids = load_similar_chunks(reference_article_id)
                print("Loaded similar chunks successfully.")
            except FileNotFoundError:
                # Load reference text and create chunks
                reference_text = get_reference_text(reference_article_id)
                reference_chunks = create_chunks(reference_text)
                
                # Load or create index
                index = load_or_create_index(reference_article_id, reference_chunks)
                
                # Get the statement and retrieve top chunks
                statement = row["Statement with Citation"]
                print("Receiving top chunks")
                response = get_top_k_similar_statements(statement, index, k)
                doc_ids = get_doc_ids(response, index)
                
                # Save the top chunks
                print("Saving top chunks")
                save_similar_chunks(doc_ids, reference_article_id)
            
            print("")

# %%
save_top_k_chunk_ids(df)
# Out:
# ------ Starting r001 ------
# r001: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r002 ------
# r002: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r003 ------
# r003: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r004 ------
# r004: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r005 ------
# r005: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r006 ------
# r006: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r007 ------
# r007: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r008 ------
# r008: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r009 ------
# r009: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r010 ------
# r010: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r011 ------
# r011: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r012 ------
# r012: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r013 ------
# r013: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r013 ------
# Loaded similar chunks successfully.
#
# ------ Starting r014 ------
# r014: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r015 ------
# r015: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r005 ------
# Loaded similar chunks successfully.
#
# ------ Starting r017 ------
# r017: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r018 ------
# r018: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r019 ------
# r019: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r020 ------
# r020: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r021 ------
# r021: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r022 ------
# r022: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r023 ------
# r023: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r024 ------
# r024: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r013 ------
# Loaded similar chunks successfully.
#
# ------ Starting r025 ------
# r025: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r026 ------
# r026: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r027 ------
# r027: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r028 ------
# r028: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r029 ------
# r029: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r030 ------
# r030: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r031 ------
# r031: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r032 ------
# r032: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r033 ------
# r033: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r034 ------
# r034: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r035 ------
# r035: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r036 ------
# r036: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r037 ------
# r037: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r038 ------
# r038: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r039 ------
# r039: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r040 ------
# r040: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r041 ------
# r041: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r042 ------
# r042: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r043 ------
# r043: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r044 ------
# r044: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r045 ------
# r045: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r046 ------
# r046: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r047 ------
# r047: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r048 ------
# r048: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r049 ------
# r049: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r050 ------
# r050: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r051 ------
# r051: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r052 ------
# r052: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r053 ------
# r053: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r051 ------
# Loaded similar chunks successfully.
#
# ------ Starting r055 ------
# r055: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r056 ------
# r056: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r057 ------
# r057: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r058 ------
# r058: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r059 ------
# r059: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r060 ------
# r060: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r061 ------
# r061: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r062 ------
# r062: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r063 ------
# r063: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r064 ------
# r064: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r065 ------
# r065: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r066 ------
# r066: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r067 ------
# r067: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r068 ------
# r068: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r069 ------
# r069: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r070 ------
# r070: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r071 ------
# r071: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r072 ------
# r072: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r074 ------
# r074: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r075 ------
# r075: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r076 ------
# r076: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r077 ------
# r077: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r078 ------
# r078: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r079 ------
# r079: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r080 ------
# r080: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r081 ------
# r081: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r081 ------
# Loaded similar chunks successfully.
#
# ------ Starting r082 ------
# r082: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r083 ------
# r083: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r084 ------
# r084: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r085 ------
# r085: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r086 ------
# r086: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r087 ------
# r087: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r087 ------
# Loaded similar chunks successfully.
#
# ------ Starting r087 ------
# Loaded similar chunks successfully.
#
# ------ Starting r088 ------
# r088: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r089 ------
# r089: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r090 ------
# r090: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r091 ------
# r091: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r092 ------
# r092: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r093 ------
# r093: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r094 ------
# r094: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r095 ------
# r095: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r096 ------
# r096: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r097 ------
# r097: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r098 ------
# r098: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r099 ------
# r099: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r100 ------
# r100: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r101 ------
# r101: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r102 ------
# r102: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r103 ------
# r103: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r104 ------
# r104: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r105 ------
# r105: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r106 ------
# r106: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r107 ------
# r107: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r108 ------
# r108: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r109 ------
# r109: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r110 ------
# r110: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r111 ------
# r111: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r112 ------
# r112: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r113 ------
# r113: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r114 ------
# r114: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r115 ------
# r115: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r116 ------
# r116: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r117 ------
# r117: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r118 ------
# r118: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r119 ------
# r119: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r120 ------
# r120: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r121 ------
# r121: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r122 ------
# r122: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r123 ------
# r123: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r124 ------
# r124: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r125 ------
# r125: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r126 ------
# r126: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r127 ------
# r127: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r128 ------
# r128: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r129 ------
# r129: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r130 ------
# r130: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r131 ------
# r131: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r132 ------
# r132: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r133 ------
# r133: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r134 ------
# r134: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r135 ------
# r135: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r136 ------
# r136: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r137 ------
# r137: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r138 ------
# r138: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r139 ------
# r139: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r140 ------
# r140: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r141 ------
# r141: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r142 ------
# r142: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r143 ------
# r143: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r144 ------
# r144: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r145 ------
# r145: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r146 ------
# r146: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r147 ------
# r147: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r148 ------
# r148: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r149 ------
# r149: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r150 ------
# r150: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r151 ------
# r151: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r152 ------
# r152: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r153 ------
# r153: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r154 ------
# r154: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r155 ------
# r155: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r156 ------
# r156: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r157 ------
# r157: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r158 ------
# r158: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r159 ------
# r159: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r160 ------
# r160: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r161 ------
# r161: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r162 ------
# r162: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r163 ------
# r163: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r164 ------
# r164: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r165 ------
# r165: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r166 ------
# r166: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r167 ------
# r167: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r168 ------
# r168: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r169 ------
# r169: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r170 ------
# r170: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r171 ------
# r171: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r172 ------
# r172: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r173 ------
# r173: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r174 ------
# r174: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r175 ------
# r175: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r176 ------
# r176: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r177 ------
# r177: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r178 ------
# r178: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r179 ------
# r179: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r180 ------
# r180: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r181 ------
# r181: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r182 ------
# r182: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r183 ------
# r183: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r184 ------
# r184: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r185 ------
# r185: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r186 ------
# r186: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r187 ------
# r187: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r188 ------
# r188: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r189 ------
# r189: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r190 ------
# r190: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r191 ------
# r191: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r192 ------
# r192: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r193 ------
# r193: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r194 ------
# r194: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r195 ------
# r195: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r196 ------
# r196: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r197 ------
# r197: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r198 ------
# r198: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r199 ------
# r199: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r200 ------
# r200: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r201 ------
# r201: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r202 ------
# r202: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r203 ------
# r203: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r204 ------
# r204: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r205 ------
# r205: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r206 ------
# r206: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r207 ------
# r207: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r208 ------
# r208: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r209 ------
# r209: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r210 ------
# r210: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r211 ------
# r211: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r212 ------
# r212: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r213 ------
# r213: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r214 ------
# r214: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r215 ------
# r215: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r216 ------
# r216: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r217 ------
# r217: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r218 ------
# r218: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r219 ------
# r219: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r220 ------
# r220: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r221 ------
# r221: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r222 ------
# r222: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r223 ------
# r223: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r224 ------
# r224: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r225 ------
# r225: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r226 ------
# r226: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r227 ------
# r227: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r228 ------
# r228: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r229 ------
# r229: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r230 ------
# r230: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r231 ------
# r231: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r232 ------
# r232: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r233 ------
# r233: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r234 ------
# r234: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r235 ------
# r235: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r236 ------
# r236: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r237 ------
# r237: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r238 ------
# r238: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r239 ------
# r239: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r240 ------
# r240: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r241 ------
# r241: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r242 ------
# r242: Loaded existing index.
# Receiving top chunks
# Saving top chunks
#
# ------ Starting r243 ------
# r243: Loaded existing index.
# Receiving top chunks
# Saving top chunks

# %%
doc_ids = load_similar_chunks(reference_article_id)
doc_texts = [index.docstore.docs[doc_id].text for doc_id in doc_ids]

# %%
def add_top_k_chunk_ids_and_texts_to_df(df, k=3):
    doc_ids_list = []
    doc_texts_list = []
    for _, row in df.iterrows():
        if row['Reference Article Downloaded'] == 'Yes':
            reference_article_id = row['Reference Article ID']
            print(f"------ Starting {reference_article_id} ------")

            # load index
            index_path = f"../data/vector_indices/{grobid_model}/{reference_article_id}/"
            storage_context = StorageContext.from_defaults(persist_dir=index_path)
            index = load_index_from_storage(storage_context)

            # load similar chunks
            doc_ids = load_similar_chunks(reference_article_id)
            doc_texts = [index.docstore.docs[doc_id].text for doc_id in doc_ids]

            # add to lists
            doc_ids_list.append(doc_ids)
            doc_texts_list.append(doc_texts)
        else:
            doc_ids_list.append(None)
            doc_texts_list.append(None)
    
    df[f'Top_{k}_Chunk_IDs'] = doc_ids_list
    df[f'Top_{k}_Chunk_Texts'] = doc_texts_list
    return df

# %%
df2 = add_top_k_chunk_ids_and_texts_to_df(df)
# Out:
# ------ Starting r001 ------
# ------ Starting r002 ------
# ------ Starting r003 ------
# ------ Starting r004 ------
# ------ Starting r005 ------
# ------ Starting r006 ------
# ------ Starting r007 ------
# ------ Starting r008 ------
# ------ Starting r009 ------
# ------ Starting r010 ------
# ------ Starting r011 ------
# ------ Starting r012 ------
# ------ Starting r013 ------
# ------ Starting r013 ------
# ------ Starting r014 ------
# ------ Starting r015 ------
# ------ Starting r005 ------
# ------ Starting r017 ------
# ------ Starting r018 ------
# ------ Starting r019 ------
# ------ Starting r020 ------
# ------ Starting r021 ------
# ------ Starting r022 ------
# ------ Starting r023 ------
# ------ Starting r024 ------
# ------ Starting r013 ------
# ------ Starting r025 ------
# ------ Starting r026 ------
# ------ Starting r027 ------
# ------ Starting r028 ------
# ------ Starting r029 ------
# ------ Starting r030 ------
# ------ Starting r031 ------
# ------ Starting r032 ------
# ------ Starting r033 ------
# ------ Starting r034 ------
# ------ Starting r035 ------
# ------ Starting r036 ------
# ------ Starting r037 ------
# ------ Starting r038 ------
# ------ Starting r039 ------
# ------ Starting r040 ------
# ------ Starting r041 ------
# ------ Starting r042 ------
# ------ Starting r043 ------
# ------ Starting r044 ------
# ------ Starting r045 ------
# ------ Starting r046 ------
# ------ Starting r047 ------
# ------ Starting r048 ------
# ------ Starting r049 ------
# ------ Starting r050 ------
# ------ Starting r051 ------
# ------ Starting r052 ------
# ------ Starting r053 ------
# ------ Starting r051 ------
# ------ Starting r055 ------
# ------ Starting r056 ------
# ------ Starting r057 ------
# ------ Starting r058 ------
# ------ Starting r059 ------
# ------ Starting r060 ------
# ------ Starting r061 ------
# ------ Starting r062 ------
# ------ Starting r063 ------
# ------ Starting r064 ------
# ------ Starting r065 ------
# ------ Starting r066 ------
# ------ Starting r067 ------
# ------ Starting r068 ------
# ------ Starting r069 ------
# ------ Starting r070 ------
# ------ Starting r071 ------
# ------ Starting r072 ------
# ------ Starting r074 ------
# ------ Starting r075 ------
# ------ Starting r076 ------
# ------ Starting r077 ------
# ------ Starting r078 ------
# ------ Starting r079 ------
# ------ Starting r080 ------
# ------ Starting r081 ------
# ------ Starting r081 ------
# ------ Starting r082 ------
# ------ Starting r083 ------
# ------ Starting r084 ------
# ------ Starting r085 ------
# ------ Starting r086 ------
# ------ Starting r087 ------
# ------ Starting r087 ------
# ------ Starting r087 ------
# ------ Starting r088 ------
# ------ Starting r089 ------
# ------ Starting r090 ------
# ------ Starting r091 ------
# ------ Starting r092 ------
# ------ Starting r093 ------
# ------ Starting r094 ------
# ------ Starting r095 ------
# ------ Starting r096 ------
# ------ Starting r097 ------
# ------ Starting r098 ------
# ------ Starting r099 ------
# ------ Starting r100 ------
# ------ Starting r101 ------
# ------ Starting r102 ------
# ------ Starting r103 ------
# ------ Starting r104 ------
# ------ Starting r105 ------
# ------ Starting r106 ------
# ------ Starting r107 ------
# ------ Starting r108 ------
# ------ Starting r109 ------
# ------ Starting r110 ------
# ------ Starting r111 ------
# ------ Starting r112 ------
# ------ Starting r113 ------
# ------ Starting r114 ------
# ------ Starting r115 ------
# ------ Starting r116 ------
# ------ Starting r117 ------
# ------ Starting r118 ------
# ------ Starting r119 ------
# ------ Starting r120 ------
# ------ Starting r121 ------
# ------ Starting r122 ------
# ------ Starting r123 ------
# ------ Starting r124 ------
# ------ Starting r125 ------
# ------ Starting r126 ------
# ------ Starting r127 ------
# ------ Starting r128 ------
# ------ Starting r129 ------
# ------ Starting r130 ------
# ------ Starting r131 ------
# ------ Starting r132 ------
# ------ Starting r133 ------
# ------ Starting r134 ------
# ------ Starting r135 ------
# ------ Starting r136 ------
# ------ Starting r137 ------
# ------ Starting r138 ------
# ------ Starting r139 ------
# ------ Starting r140 ------
# ------ Starting r141 ------
# ------ Starting r142 ------
# ------ Starting r143 ------
# ------ Starting r144 ------
# ------ Starting r145 ------
# ------ Starting r146 ------
# ------ Starting r147 ------
# ------ Starting r148 ------
# ------ Starting r149 ------
# ------ Starting r150 ------
# ------ Starting r151 ------
# ------ Starting r152 ------
# ------ Starting r153 ------
# ------ Starting r154 ------
# ------ Starting r155 ------
# ------ Starting r156 ------
# ------ Starting r157 ------
# ------ Starting r158 ------
# ------ Starting r159 ------
# ------ Starting r160 ------
# ------ Starting r161 ------
# ------ Starting r162 ------
# ------ Starting r163 ------
# ------ Starting r164 ------
# ------ Starting r165 ------
# ------ Starting r166 ------
# ------ Starting r167 ------
# ------ Starting r168 ------
# ------ Starting r169 ------
# ------ Starting r170 ------
# ------ Starting r171 ------
# ------ Starting r172 ------
# ------ Starting r173 ------
# ------ Starting r174 ------
# ------ Starting r175 ------
# ------ Starting r176 ------
# ------ Starting r177 ------
# ------ Starting r178 ------
# ------ Starting r179 ------
# ------ Starting r180 ------
# ------ Starting r181 ------
# ------ Starting r182 ------
# ------ Starting r183 ------
# ------ Starting r184 ------
# ------ Starting r185 ------
# ------ Starting r186 ------
# ------ Starting r187 ------
# ------ Starting r188 ------
# ------ Starting r189 ------
# ------ Starting r190 ------
# ------ Starting r191 ------
# ------ Starting r192 ------
# ------ Starting r193 ------
# ------ Starting r194 ------
# ------ Starting r195 ------
# ------ Starting r196 ------
# ------ Starting r197 ------
# ------ Starting r198 ------
# ------ Starting r199 ------
# ------ Starting r200 ------
# ------ Starting r201 ------
# ------ Starting r202 ------
# ------ Starting r203 ------
# ------ Starting r204 ------
# ------ Starting r205 ------
# ------ Starting r206 ------
# ------ Starting r207 ------
# ------ Starting r208 ------
# ------ Starting r209 ------
# ------ Starting r210 ------
# ------ Starting r211 ------
# ------ Starting r212 ------
# ------ Starting r213 ------
# ------ Starting r214 ------
# ------ Starting r215 ------
# ------ Starting r216 ------
# ------ Starting r217 ------
# ------ Starting r218 ------
# ------ Starting r219 ------
# ------ Starting r220 ------
# ------ Starting r221 ------
# ------ Starting r222 ------
# ------ Starting r223 ------
# ------ Starting r224 ------
# ------ Starting r225 ------
# ------ Starting r226 ------
# ------ Starting r227 ------
# ------ Starting r228 ------
# ------ Starting r229 ------
# ------ Starting r230 ------
# ------ Starting r231 ------
# ------ Starting r232 ------
# ------ Starting r233 ------
# ------ Starting r234 ------
# ------ Starting r235 ------
# ------ Starting r236 ------
# ------ Starting r237 ------
# ------ Starting r238 ------
# ------ Starting r239 ------
# ------ Starting r240 ------
# ------ Starting r241 ------
# ------ Starting r242 ------
# ------ Starting r243 ------

# %%
df2.head()
# Out:
#     Source Citing Article ID         Citing Article DOI  \
# 0  PubPeer              c001  10.1016/j.est.2021.103553
# 1  PubPeer              c001  10.1016/j.est.2021.103553
# 2  PubPeer              c002       10.1155/2022/4601350
# 3  PubPeer              c003       10.1155/2022/2408685
# 4  PubPeer              c004       10.1155/2022/4783847
#
#                                 Citing Article Title Citing Article Retracted  \
# 0  Heating a residential building using the heat ...                      Yes
# 1  Heating a residential building using the heat ...                      Yes
# 2  Oxidative Potential and Nanoantioxidant Activi...                      Yes
# 3  The Choice of Anesthetic Drugs in Outpatient H...                      Yes
# 4  A Fault-Tolerant Structure for Nano-Power Comm...                      Yes
#
#   Citing Article Downloaded       Domain  \
# 0                       Yes  Engineering
# 1                       Yes  Engineering
# 2                       Yes    Chemistry
# 3                       Yes     Medicine
# 4                       Yes  Engineering
#
#                              Statement with Citation Reference Article ID  \
# 0  Others have aimed to reduce irreversibility or...                 r001
# 1  Some researchers have also studied various hea...                 r002
# 2  The relative content of total flavonoids in th...                 r003
# 3  Research has shown that remimazolam tosylate e...                 r004
# 4  if the efficiency of the routing algorithm is ...                 r005
#
#              Reference Article DOI  \
# 0             10.1155/2021/2087027
# 1      10.1016/j.physa.2018.12.031
# 2  10.1088/1742-6596/1937/1/012038
# 3        10.1186/s12871-018-0543-3
# 4      10.36410/jcpr.2022.23.3.312
#
#                              Reference Article Title  \
# 0  A Fault Analysis Method for Three-Phase Induct...
# 1  Develop 24 dissimilar ANNs by suitable archite...
# 2  Lipid Data Acquisition for devices Treatment o...
# 3  Effect of propofol on breast cancer cell, the ...
# 4  Analysis and research hotspots of ceramic mate...
#
#                           Reference Article Abstract  \
# 0  The fault prediction and abductive fault diagn...
# 1  The artificial neural network optimization met...
# 2  Recently, the widespread deployment of smart p...
# 3  Breast cancer is the second leading cause of c...
# 4  From the perspective of scientometrics, comb t...
#
#   Reference Article PDF Available Reference Article Retracted  \
# 0                             Yes                          No
# 1                             Yes                          No
# 2                             Yes                          No
# 3                             Yes                          No
# 4                             Yes                          No
#
#   Reference Article Downloaded           Label Explanation  \
# 0                          Yes  Unsubstantiate  Irrelevant
# 1                          Yes  Unsubstantiate  Irrelevant
# 2                          Yes  Unsubstantiate  Irrelevant
# 3                          Yes  Unsubstantiate  Irrelevant
# 4                          Yes  Unsubstantiate  Irrelevant
#
#                                      Top_3_Chunk_IDs  \
# 0  [66ce2c05-0e4b-48dd-a146-b131119b32b4, 23ff46b...
# 1  [1eee1d68-3311-453d-9b1f-003bfd410db9, ba602d1...
# 2  [5c343544-9684-47c6-9a60-04b3fbfaece4, f602dee...
# 3  [ae9ef0d1-eb32-4246-a315-da0067c2060a, 416cfc7...
# 4  [69e069c2-d1de-4017-8660-0de9f5e6a36e, be0d8b8...
#
#                                    Top_3_Chunk_Texts
# 0  [Transactions on Cybernetics\n\t\t\n\t\t\t51\n...
# 1  [J. Exergy\n\t\t\n\t\t\t22\n\t\t\t2\n\t\t\t\n\...
# 2  [AND RESULTPhotochemical blood performance of ...
# 3  [Rep\n\t\t\n\t\t\t37\n\t\t\t2\n\t\t\t\n\t\t\t2...
# 4  [with high centrality are usually the main nod...

# %%
df2.to_pickle(f'../data/dfs/{grobid_model}/ReferenceErrorDetection_data_with_chunk_info.pkl')

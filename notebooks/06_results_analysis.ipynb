# %% [markdown]
# # Result Analysis

# %%
models = ["gpt-3.5-turbo-0125", "gpt-4.1-nano-2025-04-14", "gpt-4.1-mini-2025-04-14", "gpt-4.1-2025-04-14", "llama3.1.70b", "llama4.scout"]
chunkings = ["256_20", "1024_20"]
only_texts = [False, True]

# %%
# %run ../scripts/load_df_for_analysis.py

# %%
# %run ../scripts/df_calculations.py

# %% [markdown]
# ## Gather Results: Model Comparison

# %%
all_results = {}

# %%
def gather_results(chunking, only_text, model):
    global all_results

    df = load_df_for_analysis(chunking, only_text, model)
    
    results = eval_predictions(df, include_relabelled_partially=True)
    results_without_relabelled = eval_predictions(df, include_relabelled_partially=False)

    if model not in all_results:
        all_results[model] = {}
    all_results[model][f"{'only_text_' if only_text else ''}{chunking}"] = {
        "all": results,
        "without_relabelled": results_without_relabelled,
    }

# %% [markdown]
# ### Hyperparameters for all evaluations:
# - PDF text from reference was extracted with large GROBID model
# - Ollama indexing for choosing best chunks: used text-embedding-3-large from OpenAI, chunking with SentenceSplitter, detected top 3 matching chunks for statement
# - Model temperature is set to 0
#
# ### Hyperparameters here evaluated:
# - only_text: If this is "True", then the scientific text from the TEI file from GROBID was extracted via code - Else the whole text from the TEI document (including sources, authors, ...) was included for choosing the best chunks
# - chunking: chunk size is set to either 256 or 1024, token overlap is always kept at 20
# - model: different models are evaluated and compared for the actual classification part

# %% [markdown]
# ### GPT 3.5 Turbo

# %%
model = "gpt-3.5-turbo-0125"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Row 21 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 21 Model Classification Label is not a valid label: None
# Row 21 Model Classification Label is not a valid label: None
# Row 21 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 21 Model Classification Label is not a valid label: None
# Row 21 Model Classification Label is not a valid label: None
# Row 24 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 24 Model Classification Label is not a valid label: None
# Row 24 Model Classification Label is not a valid label: None
# Row 21 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 24 Model Classification could not be decoded: Expecting value: line 1 column 1 (char 0)
#
# Row 21 Model Classification Label is not a valid label: None
# Row 24 Model Classification Label is not a valid label: None
# Row 21 Model Classification Label is not a valid label: None
# Row 24 Model Classification Label is not a valid label: None

# %% [markdown]
# ### GPT 4.1 Nano

# %%
model = "gpt-4.1-nano-2025-04-14"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Error gathering results for gpt-4.1-nano-2025-04-14, chunking: 1024_20, only_text: True: [Errno 2] No such file or directory: '../data/dfs/only_text_1024_20/gpt-4.1-nano-2025-04-14/ReferenceErrorDetection_data_with_prompt_results.pkl'

# %% [markdown]
# ### GPT 4.1 Mini

# %%
model = "gpt-4.1-mini-2025-04-14"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        try:
            gather_results(chunking, only_text, model)
        except Exception as e:
            print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Error gathering results for gpt-4.1-mini-2025-04-14, chunking: 1024_20, only_text: True: [Errno 2] No such file or directory: '../data/dfs/only_text_1024_20/gpt-4.1-mini-2025-04-14/ReferenceErrorDetection_data_with_prompt_results.pkl'

# %% [markdown]
# ### Llama 3.1:70b

# %%
model = "llama3.1.70b"

# %%
for chunking in chunkings:
    for only_text in only_texts:
        # try:
        gather_results(chunking, only_text, model)
        # except Exception as e:
        #     print(f"Error gathering results for {model}, chunking: {chunking}, only_text: {only_text}: {e}")
# Out:
# Row 81 Model Classification could not be decoded: 'label'
# {
#   "citation": null,
#   "conclusion": null,
#   "introduction": null,
#   "methodology": [
#     "Atomic force microscopy force spectroscopy and trans-epithelial electrical resistance assessed changes in cell-cell tethering and paracellular permeability respectively.",
#     "Carboxyfluorescein dye uptake, ATP-biosensing, and western blotting were used to assess the ability of Peptide 5 to block hemichannel activity, ATP-release, and ultimately disassembly of the adherens/tight junction complex."
#   ],
#   "question": null,
#   "results": [
#     "Co-incubation of TGF-β1 with Peptide 5 significantly reduced dye uptake and restored ATP release to near basal.",
#     "Peptide 5 successfully prevented TGF-β1-evoked changes in expression of E-cadherin, N-cadherin, Claudin-2, and ZO-1 in human primary renal proximal tubule cells.",
#     "Cx43 +/- mice exhibited minimal disassembly of the adherens and tight junction complex."
#   ]
# }
# Row 81 Model Classification Label is not a valid label: None
# Row 81 Model Classification Label is not a valid label: None

# %% [markdown]
# ### Save results

# %%
import json

with open("../data/all_results.json", "w") as json_file:
    json.dump(all_results, json_file, indent=4)

# %% [markdown]
# ## Reproduce Table from Paper

# %%
results_for_table = all_results['te3l_no_prev_chunking']['full_model']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 results_for_table = all_results['te3l_no_prev_chunking']['full_model']
#
# KeyError: 'te3l_no_prev_chunking'

# %%
results_for_table
# Out:
# {'gpt-3.5-turbo-0125': {'all_labels': {'accuracy': 0.567,
#    'total': 247,
#    'correct': 140,
#    'false_predictions': 107,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 78,
#      'partially substantiate': 16,
#      'fully substantiate': 14,
#      'invalid label': 1},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 2,
#      'partially substantiate': 7,
#      'fully substantiate': 5,
#      'invalid label': 0},
#     'fully substantiate': {'total': 124,
#      'unsubstantiate': 11,
#      'partially substantiate': 58,
#      'fully substantiate': 55,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.57,
#    'total': 244,
#    'correct': 139,
#    'false_predictions': 105,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 78,
#      'partially substantiate': 15,
#      'fully substantiate': 14,
#      'invalid label': 1},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 2,
#      'partially substantiate': 7,
#      'fully substantiate': 5,
#      'invalid label': 0},
#     'fully substantiate': {'total': 122,
#      'unsubstantiate': 10,
#      'partially substantiate': 58,
#      'fully substantiate': 54,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.822,
#    'total': 247,
#    'correct': 203,
#    'false_predictions': 44,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 78,
#      'fully substantiate': 30,
#      'invalid label': 1},
#     'fully substantiate': {'total': 138,
#      'unsubstantiate': 13,
#      'fully substantiate': 125,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.828,
#    'total': 244,
#    'correct': 202,
#    'false_predictions': 42,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 78,
#      'fully substantiate': 29,
#      'invalid label': 1},
#     'fully substantiate': {'total': 136,
#      'unsubstantiate': 12,
#      'fully substantiate': 124,
#      'invalid label': 0}}}},
#  'gpt-4-0125-preview': {'all_labels': {'accuracy': 0.7,
#    'total': 247,
#    'correct': 173,
#    'false_predictions': 74,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 93,
#      'partially substantiate': 4,
#      'fully substantiate': 12,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 5,
#      'partially substantiate': 2,
#      'fully substantiate': 7,
#      'invalid label': 0},
#     'fully substantiate': {'total': 124,
#      'unsubstantiate': 19,
#      'partially substantiate': 27,
#      'fully substantiate': 78,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.701,
#    'total': 244,
#    'correct': 171,
#    'false_predictions': 73,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 92,
#      'partially substantiate': 4,
#      'fully substantiate': 12,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 5,
#      'partially substantiate': 2,
#      'fully substantiate': 7,
#      'invalid label': 0},
#     'fully substantiate': {'total': 122,
#      'unsubstantiate': 18,
#      'partially substantiate': 27,
#      'fully substantiate': 77,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.838,
#    'total': 247,
#    'correct': 207,
#    'false_predictions': 40,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 93,
#      'fully substantiate': 16,
#      'invalid label': 0},
#     'fully substantiate': {'total': 138,
#      'unsubstantiate': 24,
#      'fully substantiate': 114,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.84,
#    'total': 244,
#    'correct': 205,
#    'false_predictions': 39,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 92,
#      'fully substantiate': 16,
#      'invalid label': 0},
#     'fully substantiate': {'total': 136,
#      'unsubstantiate': 23,
#      'fully substantiate': 113,
#      'invalid label': 0}}}},
#  'gpt-4o-2024-05-13': {'all_labels': {'accuracy': 0.587,
#    'total': 247,
#    'correct': 145,
#    'false_predictions': 102,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 92,
#      'partially substantiate': 11,
#      'fully substantiate': 6,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 3,
#      'partially substantiate': 8,
#      'fully substantiate': 3,
#      'invalid label': 0},
#     'fully substantiate': {'total': 124,
#      'unsubstantiate': 23,
#      'partially substantiate': 56,
#      'fully substantiate': 45,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.586,
#    'total': 244,
#    'correct': 143,
#    'false_predictions': 101,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 91,
#      'partially substantiate': 11,
#      'fully substantiate': 6,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 3,
#      'partially substantiate': 8,
#      'fully substantiate': 3,
#      'invalid label': 0},
#     'fully substantiate': {'total': 122,
#      'unsubstantiate': 22,
#      'partially substantiate': 56,
#      'fully substantiate': 44,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.826,
#    'total': 247,
#    'correct': 204,
#    'false_predictions': 43,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 92,
#      'fully substantiate': 17,
#      'invalid label': 0},
#     'fully substantiate': {'total': 138,
#      'unsubstantiate': 26,
#      'fully substantiate': 112,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.828,
#    'total': 244,
#    'correct': 202,
#    'false_predictions': 42,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 91,
#      'fully substantiate': 17,
#      'invalid label': 0},
#     'fully substantiate': {'total': 136,
#      'unsubstantiate': 25,
#      'fully substantiate': 111,
#      'invalid label': 0}}}},
#  'llama3.1:70b': {'all_labels': {'accuracy': 0.559,
#    'total': 247,
#    'correct': 138,
#    'false_predictions': 109,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 95,
#      'partially substantiate': 10,
#      'fully substantiate': 4,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 4,
#      'partially substantiate': 9,
#      'fully substantiate': 1,
#      'invalid label': 0},
#     'fully substantiate': {'total': 124,
#      'unsubstantiate': 33,
#      'partially substantiate': 57,
#      'fully substantiate': 34,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.557,
#    'total': 244,
#    'correct': 136,
#    'false_predictions': 108,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 94,
#      'partially substantiate': 10,
#      'fully substantiate': 4,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 4,
#      'partially substantiate': 9,
#      'fully substantiate': 1,
#      'invalid label': 0},
#     'fully substantiate': {'total': 122,
#      'unsubstantiate': 32,
#      'partially substantiate': 57,
#      'fully substantiate': 33,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.794,
#    'total': 247,
#    'correct': 196,
#    'false_predictions': 51,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 95,
#      'fully substantiate': 14,
#      'invalid label': 0},
#     'fully substantiate': {'total': 138,
#      'unsubstantiate': 37,
#      'fully substantiate': 101,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.795,
#    'total': 244,
#    'correct': 194,
#    'false_predictions': 50,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 94,
#      'fully substantiate': 14,
#      'invalid label': 0},
#     'fully substantiate': {'total': 136,
#      'unsubstantiate': 36,
#      'fully substantiate': 100,
#      'invalid label': 0}}}},
#  'llama3.1:405b': {'all_labels': {'accuracy': 0.543,
#    'total': 247,
#    'correct': 134,
#    'false_predictions': 113,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 95,
#      'partially substantiate': 9,
#      'fully substantiate': 5,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 5,
#      'partially substantiate': 7,
#      'fully substantiate': 2,
#      'invalid label': 0},
#     'fully substantiate': {'total': 124,
#      'unsubstantiate': 34,
#      'partially substantiate': 58,
#      'fully substantiate': 32,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.541,
#    'total': 244,
#    'correct': 132,
#    'false_predictions': 112,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 94,
#      'partially substantiate': 9,
#      'fully substantiate': 5,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 5,
#      'partially substantiate': 7,
#      'fully substantiate': 2,
#      'invalid label': 0},
#     'fully substantiate': {'total': 122,
#      'unsubstantiate': 33,
#      'partially substantiate': 58,
#      'fully substantiate': 31,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.785,
#    'total': 247,
#    'correct': 194,
#    'false_predictions': 53,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 95,
#      'fully substantiate': 14,
#      'invalid label': 0},
#     'fully substantiate': {'total': 138,
#      'unsubstantiate': 39,
#      'fully substantiate': 99,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.787,
#    'total': 244,
#    'correct': 192,
#    'false_predictions': 52,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 94,
#      'fully substantiate': 14,
#      'invalid label': 0},
#     'fully substantiate': {'total': 136,
#      'unsubstantiate': 38,
#      'fully substantiate': 98,
#      'invalid label': 0}}}},
#  'llama3.3': {'all_labels': {'accuracy': 0.514,
#    'total': 247,
#    'correct': 127,
#    'false_predictions': 120,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 98,
#      'partially substantiate': 8,
#      'fully substantiate': 3,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 7,
#      'partially substantiate': 7,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 124,
#      'unsubstantiate': 47,
#      'partially substantiate': 55,
#      'fully substantiate': 22,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.512,
#    'total': 244,
#    'correct': 125,
#    'false_predictions': 119,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 97,
#      'partially substantiate': 8,
#      'fully substantiate': 3,
#      'invalid label': 0},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 7,
#      'partially substantiate': 7,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 122,
#      'unsubstantiate': 46,
#      'partially substantiate': 55,
#      'fully substantiate': 21,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.737,
#    'total': 247,
#    'correct': 182,
#    'false_predictions': 65,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 98,
#      'fully substantiate': 11,
#      'invalid label': 0},
#     'fully substantiate': {'total': 138,
#      'unsubstantiate': 54,
#      'fully substantiate': 84,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.738,
#    'total': 244,
#    'correct': 180,
#    'false_predictions': 64,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 97,
#      'fully substantiate': 11,
#      'invalid label': 0},
#     'fully substantiate': {'total': 136,
#      'unsubstantiate': 53,
#      'fully substantiate': 83,
#      'invalid label': 0}}}},
#  'llama4:scout': {'all_labels': {'accuracy': 0.559,
#    'total': 247,
#    'correct': 138,
#    'false_predictions': 109,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 94,
#      'partially substantiate': 12,
#      'fully substantiate': 2,
#      'invalid label': 1},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 5,
#      'partially substantiate': 8,
#      'fully substantiate': 1,
#      'invalid label': 0},
#     'fully substantiate': {'total': 124,
#      'unsubstantiate': 29,
#      'partially substantiate': 59,
#      'fully substantiate': 36,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.557,
#    'total': 244,
#    'correct': 136,
#    'false_predictions': 108,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 93,
#      'partially substantiate': 12,
#      'fully substantiate': 2,
#      'invalid label': 1},
#     'partially substantiate': {'total': 14,
#      'unsubstantiate': 5,
#      'partially substantiate': 8,
#      'fully substantiate': 1,
#      'invalid label': 0},
#     'fully substantiate': {'total': 122,
#      'unsubstantiate': 28,
#      'partially substantiate': 59,
#      'fully substantiate': 35,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.802,
#    'total': 247,
#    'correct': 198,
#    'false_predictions': 49,
#    'type_predictions': {'unsubstantiate': {'total': 109,
#      'unsubstantiate': 94,
#      'fully substantiate': 14,
#      'invalid label': 1},
#     'fully substantiate': {'total': 138,
#      'unsubstantiate': 34,
#      'fully substantiate': 104,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.803,
#    'total': 244,
#    'correct': 196,
#    'false_predictions': 48,
#    'type_predictions': {'unsubstantiate': {'total': 108,
#      'unsubstantiate': 93,
#      'fully substantiate': 14,
#      'invalid label': 1},
#     'fully substantiate': {'total': 136,
#      'unsubstantiate': 33,
#      'fully substantiate': 103,
#      'invalid label': 0}}}},
#  'llama3.1:70b_annotated': {'all_labels': {'accuracy': 0.53,
#    'total': 247,
#    'correct': 131,
#    'false_predictions': 116,
#    'type_predictions': {'unsubstantiate': {'total': 116,
#      'unsubstantiate': 97,
#      'partially substantiate': 15,
#      'fully substantiate': 4,
#      'invalid label': 0},
#     'partially substantiate': {'total': 0,
#      'unsubstantiate': 0,
#      'partially substantiate': 0,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 131,
#      'unsubstantiate': 36,
#      'partially substantiate': 61,
#      'fully substantiate': 34,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.529,
#    'total': 244,
#    'correct': 129,
#    'false_predictions': 115,
#    'type_predictions': {'unsubstantiate': {'total': 115,
#      'unsubstantiate': 96,
#      'partially substantiate': 15,
#      'fully substantiate': 4,
#      'invalid label': 0},
#     'partially substantiate': {'total': 0,
#      'unsubstantiate': 0,
#      'partially substantiate': 0,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 129,
#      'unsubstantiate': 35,
#      'partially substantiate': 61,
#      'fully substantiate': 33,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.777,
#    'total': 247,
#    'correct': 192,
#    'false_predictions': 55,
#    'type_predictions': {'unsubstantiate': {'total': 116,
#      'unsubstantiate': 97,
#      'fully substantiate': 19,
#      'invalid label': 0},
#     'fully substantiate': {'total': 131,
#      'unsubstantiate': 36,
#      'fully substantiate': 95,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.779,
#    'total': 244,
#    'correct': 190,
#    'false_predictions': 54,
#    'type_predictions': {'unsubstantiate': {'total': 115,
#      'unsubstantiate': 96,
#      'fully substantiate': 19,
#      'invalid label': 0},
#     'fully substantiate': {'total': 129,
#      'unsubstantiate': 35,
#      'fully substantiate': 94,
#      'invalid label': 0}}}},
#  'llama3.1:70b_annotated_corrected_statements': {'all_labels': {'accuracy': 0.555,
#    'total': 247,
#    'correct': 137,
#    'false_predictions': 110,
#    'type_predictions': {'unsubstantiate': {'total': 116,
#      'unsubstantiate': 100,
#      'partially substantiate': 13,
#      'fully substantiate': 3,
#      'invalid label': 0},
#     'partially substantiate': {'total': 0,
#      'unsubstantiate': 0,
#      'partially substantiate': 0,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 131,
#      'unsubstantiate': 35,
#      'partially substantiate': 59,
#      'fully substantiate': 37,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.553,
#    'total': 244,
#    'correct': 135,
#    'false_predictions': 109,
#    'type_predictions': {'unsubstantiate': {'total': 115,
#      'unsubstantiate': 99,
#      'partially substantiate': 13,
#      'fully substantiate': 3,
#      'invalid label': 0},
#     'partially substantiate': {'total': 0,
#      'unsubstantiate': 0,
#      'partially substantiate': 0,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 129,
#      'unsubstantiate': 34,
#      'partially substantiate': 59,
#      'fully substantiate': 36,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.794,
#    'total': 247,
#    'correct': 196,
#    'false_predictions': 51,
#    'type_predictions': {'unsubstantiate': {'total': 116,
#      'unsubstantiate': 100,
#      'fully substantiate': 16,
#      'invalid label': 0},
#     'fully substantiate': {'total': 131,
#      'unsubstantiate': 35,
#      'fully substantiate': 96,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.795,
#    'total': 244,
#    'correct': 194,
#    'false_predictions': 50,
#    'type_predictions': {'unsubstantiate': {'total': 115,
#      'unsubstantiate': 99,
#      'fully substantiate': 16,
#      'invalid label': 0},
#     'fully substantiate': {'total': 129,
#      'unsubstantiate': 34,
#      'fully substantiate': 95,
#      'invalid label': 0}}}},
#  'llama3.1:70b_two_labels_annotated': {'all_labels': {'accuracy': 0.713,
#    'total': 247,
#    'correct': 176,
#    'false_predictions': 71,
#    'type_predictions': {'unsubstantiate': {'total': 116,
#      'unsubstantiate': 104,
#      'partially substantiate': 0,
#      'fully substantiate': 12,
#      'invalid label': 0},
#     'partially substantiate': {'total': 0,
#      'unsubstantiate': 0,
#      'partially substantiate': 0,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 131,
#      'unsubstantiate': 59,
#      'partially substantiate': 0,
#      'fully substantiate': 72,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.713,
#    'total': 244,
#    'correct': 174,
#    'false_predictions': 70,
#    'type_predictions': {'unsubstantiate': {'total': 115,
#      'unsubstantiate': 103,
#      'partially substantiate': 0,
#      'fully substantiate': 12,
#      'invalid label': 0},
#     'partially substantiate': {'total': 0,
#      'unsubstantiate': 0,
#      'partially substantiate': 0,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 129,
#      'unsubstantiate': 58,
#      'partially substantiate': 0,
#      'fully substantiate': 71,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.713,
#    'total': 247,
#    'correct': 176,
#    'false_predictions': 71,
#    'type_predictions': {'unsubstantiate': {'total': 116,
#      'unsubstantiate': 104,
#      'fully substantiate': 12,
#      'invalid label': 0},
#     'fully substantiate': {'total': 131,
#      'unsubstantiate': 59,
#      'fully substantiate': 72,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.713,
#    'total': 244,
#    'correct': 174,
#    'false_predictions': 70,
#    'type_predictions': {'unsubstantiate': {'total': 115,
#      'unsubstantiate': 103,
#      'fully substantiate': 12,
#      'invalid label': 0},
#     'fully substantiate': {'total': 129,
#      'unsubstantiate': 58,
#      'fully substantiate': 71,
#      'invalid label': 0}}}},
#  'llama3.1:70b_two_labels_annotated_corrected_statements': {'all_labels': {'accuracy': 0.704,
#    'total': 247,
#    'correct': 174,
#    'false_predictions': 73,
#    'type_predictions': {'unsubstantiate': {'total': 116,
#      'unsubstantiate': 106,
#      'partially substantiate': 0,
#      'fully substantiate': 10,
#      'invalid label': 0},
#     'partially substantiate': {'total': 0,
#      'unsubstantiate': 0,
#      'partially substantiate': 0,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 131,
#      'unsubstantiate': 63,
#      'partially substantiate': 0,
#      'fully substantiate': 68,
#      'invalid label': 0}}},
#   'all_labels_exclude_not_available': {'accuracy': 0.705,
#    'total': 244,
#    'correct': 172,
#    'false_predictions': 72,
#    'type_predictions': {'unsubstantiate': {'total': 115,
#      'unsubstantiate': 105,
#      'partially substantiate': 0,
#      'fully substantiate': 10,
#      'invalid label': 0},
#     'partially substantiate': {'total': 0,
#      'unsubstantiate': 0,
#      'partially substantiate': 0,
#      'fully substantiate': 0,
#      'invalid label': 0},
#     'fully substantiate': {'total': 129,
#      'unsubstantiate': 62,
#      'partially substantiate': 0,
#      'fully substantiate': 67,
#      'invalid label': 0}}},
#   'two_labels': {'accuracy': 0.704,
#    'total': 247,
#    'correct': 174,
#    'false_predictions': 73,
#    'type_predictions': {'unsubstantiate': {'total': 116,
#      'unsubstantiate': 106,
#      'fully substantiate': 10,
#      'invalid label': 0},
#     'fully substantiate': {'total': 131,
#      'unsubstantiate': 63,
#      'fully substantiate': 68,
#      'invalid label': 0}}},
#   'two_labels_exclude_not_available': {'accuracy': 0.705,
#    'total': 244,
#    'correct': 172,
#    'false_predictions': 72,
#    'type_predictions': {'unsubstantiate': {'total': 115,
#      'unsubstantiate': 105,
#      'fully substantiate': 10,
#      'invalid label': 0},
#     'fully substantiate': {'total': 129,
#      'unsubstantiate': 62,
#      'fully substantiate': 67,
#      'invalid label': 0}}}}}

# %%
print("Label Accuracies - Include All Downloaded")
print_table_label_accuracies(calc_label_accuracies(results_for_table))
# Out:
# Label Accuracies - Include All Downloaded
# +--------------------------------------------------------+------+-----------+-------+---------+
# |                         Model                          |  Un  | Partially | Fully | Overall |
# +--------------------------------------------------------+------+-----------+-------+---------+
# |                   gpt-3.5-turbo-0125                   | 71.6 |   50.0    | 44.4  |  56.7   |
# |                   gpt-4-0125-preview                   | 85.3 |   14.3    | 62.9  |  70.0   |
# |                   gpt-4o-2024-05-13                    | 84.4 |   57.1    | 36.3  |  58.7   |
# |                      llama3.1:70b                      | 87.2 |   64.3    | 27.4  |  55.9   |
# |                     llama3.1:405b                      | 87.2 |   50.0    | 25.8  |  54.3   |
# |                        llama3.3                        | 89.9 |   50.0    | 17.7  |  51.4   |
# |                      llama4:scout                      | 86.2 |   57.1    | 29.0  |  55.9   |
# |                 llama3.1:70b_annotated                 | 83.6 |    0.0    | 26.0  |  53.0   |
# |      llama3.1:70b_annotated_corrected_statements       | 86.2 |    0.0    | 28.2  |  55.5   |
# |           llama3.1:70b_two_labels_annotated            | 89.7 |    0.0    | 55.0  |  71.3   |
# | llama3.1:70b_two_labels_annotated_corrected_statements | 91.4 |    0.0    | 51.9  |  70.4   |
# +--------------------------------------------------------+------+-----------+-------+---------+

# %%
print("Label Accuracies - Exclude Not Available in Paper")
print_table_label_accuracies(calc_label_accuracies(results_for_table, True))
# Out:
# Label Accuracies - Exclude Not Available in Paper
# +--------------------------------------------------------+------+-----------+-------+---------+
# |                         Model                          |  Un  | Partially | Fully | Overall |
# +--------------------------------------------------------+------+-----------+-------+---------+
# |                   gpt-3.5-turbo-0125                   | 72.2 |   50.0    | 44.3  |  57.0   |
# |                   gpt-4-0125-preview                   | 85.2 |   14.3    | 63.1  |  70.1   |
# |                   gpt-4o-2024-05-13                    | 84.3 |   57.1    | 36.1  |  58.6   |
# |                      llama3.1:70b                      | 87.0 |   64.3    | 27.0  |  55.7   |
# |                     llama3.1:405b                      | 87.0 |   50.0    | 25.4  |  54.1   |
# |                        llama3.3                        | 89.8 |   50.0    | 17.2  |  51.2   |
# |                      llama4:scout                      | 86.1 |   57.1    | 28.7  |  55.7   |
# |                 llama3.1:70b_annotated                 | 83.5 |    0.0    | 25.6  |  52.9   |
# |      llama3.1:70b_annotated_corrected_statements       | 86.1 |    0.0    | 27.9  |  55.3   |
# |           llama3.1:70b_two_labels_annotated            | 89.6 |    0.0    | 55.0  |  71.3   |
# | llama3.1:70b_two_labels_annotated_corrected_statements | 91.3 |    0.0    | 51.9  |  70.5   |
# +--------------------------------------------------------+------+-----------+-------+---------+

# %% [markdown]
# ### Compare to paper results

# %%
calc_label_accuracies(results_for_table)
# Out:
# {'gpt-3.5-turbo-0125': {'unsubstantiate': 0.716,
#   'partially substantiate': 0.5,
#   'fully substantiate': 0.444,
#   'overall': 0.567},
#  'gpt-4-0125-preview': {'unsubstantiate': 0.853,
#   'partially substantiate': 0.143,
#   'fully substantiate': 0.629,
#   'overall': 0.7},
#  'gpt-4o-2024-05-13': {'unsubstantiate': 0.844,
#   'partially substantiate': 0.571,
#   'fully substantiate': 0.363,
#   'overall': 0.587},
#  'llama3.1:70b': {'unsubstantiate': 0.872,
#   'partially substantiate': 0.643,
#   'fully substantiate': 0.274,
#   'overall': 0.559},
#  'llama3.1:405b': {'unsubstantiate': 0.872,
#   'partially substantiate': 0.5,
#   'fully substantiate': 0.258,
#   'overall': 0.543},
#  'llama3.3': {'unsubstantiate': 0.899,
#   'partially substantiate': 0.5,
#   'fully substantiate': 0.177,
#   'overall': 0.514},
#  'llama4:scout': {'unsubstantiate': 0.862,
#   'partially substantiate': 0.571,
#   'fully substantiate': 0.29,
#   'overall': 0.559},
#  'llama3.1:70b_annotated': {'unsubstantiate': 0.836,
#   'partially substantiate': 0,
#   'fully substantiate': 0.26,
#   'overall': 0.53},
#  'llama3.1:70b_annotated_corrected_statements': {'unsubstantiate': 0.862,
#   'partially substantiate': 0,
#   'fully substantiate': 0.282,
#   'overall': 0.555},
#  'llama3.1:70b_two_labels_annotated': {'unsubstantiate': 0.897,
#   'partially substantiate': 0,
#   'fully substantiate': 0.55,
#   'overall': 0.713},
#  'llama3.1:70b_two_labels_annotated_corrected_statements': {'unsubstantiate': 0.914,
#   'partially substantiate': 0,
#   'fully substantiate': 0.519,
#   'overall': 0.704}}

# %%
paper_results = {
    'gpt-3.5-turbo-0125': {
        'unsubstantiate': 0.795,
        'partially substantiate': 0.571,
        'fully substantiate': 0.306,
        'overall': 0.540,
    },
    'gpt-4-0125-preview': {
        'unsubstantiate': 0.839,
        'partially substantiate': 0.214,
        'fully substantiate': 0.629,
        'overall': 0.700,
    },
    'gpt-4o-2024-05-13': {
        'unsubstantiate': 0.866,
        'partially substantiate': 0.500,
        'fully substantiate': 0.347,
        'overall': 0.588,
    },
}

# %%
def calc_difference_between_results(calculated_results, paper_results):
    differences = {}
    for model, results in paper_results.items():
        if model in calculated_results:
            differences[model] = {
                key: calculated_results[model][key] - value
                for key, value in results.items()
            }
    return differences

# %%
calc_difference_between_results(calc_label_accuracies(results_for_table), paper_results)
# Out:
# {'gpt-3.5-turbo-0125': {'unsubstantiate': -0.07900000000000007,
#   'partially substantiate': -0.07099999999999995,
#   'fully substantiate': 0.138,
#   'overall': 0.026999999999999913},
#  'gpt-4-0125-preview': {'unsubstantiate': 0.014000000000000012,
#   'partially substantiate': -0.07100000000000001,
#   'fully substantiate': 0.0,
#   'overall': 0.0},
#  'gpt-4o-2024-05-13': {'unsubstantiate': -0.02200000000000002,
#   'partially substantiate': 0.07099999999999995,
#   'fully substantiate': 0.016000000000000014,
#   'overall': -0.0010000000000000009}}

# %%
label_accuracies = calc_label_accuracies(results_for_table, True)
print("Label Accuracies - Exclude Not Available in Paper")
print_table_label_accuracies(label_accuracies)
print("")
print("Paper Results")
print_table_label_accuracies(paper_results)
print("")
print("Differences from paper results to calculated paper results")
print_table_label_accuracies(calc_difference_between_results(label_accuracies, paper_results))
# Out:
# Label Accuracies - Exclude Not Available in Paper
# +--------------------------------------------------------+------+-----------+-------+---------+
# |                         Model                          |  Un  | Partially | Fully | Overall |
# +--------------------------------------------------------+------+-----------+-------+---------+
# |                   gpt-3.5-turbo-0125                   | 72.2 |   50.0    | 44.3  |  57.0   |
# |                   gpt-4-0125-preview                   | 85.2 |   14.3    | 63.1  |  70.1   |
# |                   gpt-4o-2024-05-13                    | 84.3 |   57.1    | 36.1  |  58.6   |
# |                      llama3.1:70b                      | 87.0 |   64.3    | 27.0  |  55.7   |
# |                     llama3.1:405b                      | 87.0 |   50.0    | 25.4  |  54.1   |
# |                        llama3.3                        | 89.8 |   50.0    | 17.2  |  51.2   |
# |                      llama4:scout                      | 86.1 |   57.1    | 28.7  |  55.7   |
# |                 llama3.1:70b_annotated                 | 83.5 |    0.0    | 25.6  |  52.9   |
# |      llama3.1:70b_annotated_corrected_statements       | 86.1 |    0.0    | 27.9  |  55.3   |
# |           llama3.1:70b_two_labels_annotated            | 89.6 |    0.0    | 55.0  |  71.3   |
# | llama3.1:70b_two_labels_annotated_corrected_statements | 91.3 |    0.0    | 51.9  |  70.5   |
# +--------------------------------------------------------+------+-----------+-------+---------+
#
# Paper Results
# +--------------------+------+-----------+-------+---------+
# |       Model        |  Un  | Partially | Fully | Overall |
# +--------------------+------+-----------+-------+---------+
# | gpt-3.5-turbo-0125 | 79.5 |   57.1    | 30.6  |  54.0   |
# | gpt-4-0125-preview | 83.9 |   21.4    | 62.9  |  70.0   |
# | gpt-4o-2024-05-13  | 86.6 |   50.0    | 34.7  |  58.8   |
# +--------------------+------+-----------+-------+---------+
#
# Differences from paper results to calculated paper results
# +--------------------+------+-----------+-------+---------+
# |       Model        |  Un  | Partially | Fully | Overall |
# +--------------------+------+-----------+-------+---------+
# | gpt-3.5-turbo-0125 | -7.3 |   -7.1    | 13.7  |   3.0   |
# | gpt-4-0125-preview | 1.3  |   -7.1    |  0.2  |   0.1   |
# | gpt-4o-2024-05-13  | -2.3 |    7.1    |  1.4  |  -0.2   |
# +--------------------+------+-----------+-------+---------+
